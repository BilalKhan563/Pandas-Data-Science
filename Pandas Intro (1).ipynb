# %%
import pandas as pd

# %%
#  1 Dimensional Series
mobile = pd.Series(['Huawei', 'Oppo', 'Iphone'])
mobile
# Out:
# 0    Huawei
# 1      Oppo
# 2    Iphone
# dtype: object

# %%
# 1 Dimensional Series
bag = pd.Series(['Register', 'Pen', 'Sheet'])
bag
# Out:
# 0    Register
# 1         Pen
# 2       Sheet
# dtype: object

# %%
# 2 Dimesnional Data : DataFrame
dataframe = pd.DataFrame({"Eectronic: switch" , "Item: bag"})
dataframe
# Out:
#                    0
# 0          Item: bag
# 1  Eectronic: switch

# %% [markdown]
# # How to Import Data

# %%
# How to IMport Data
# MOst common Files Format CSV : Comma Separated Values
phone = pd.read_csv("phone.csv")

# %%
phone
# Out:
#        phone   memory(mb)    price    demand  supply
# 0  motorolla         12.0   $1,000      20.0    14.0
# 1    samsung         10.0   $8,799      40.0    18.0
# 2      nokia         18.0   $9,799      60.0    26.0
# 3     huawei         98.0   $9,890      16.0     2.0
# 4     Iphone         67.0  $90,909      22.0     8.0
# 5         LG         77.0   $8,686      26.0   200.0
# 6       Oppo         99.0   $5,778      23.0    19.0
# 7       Vovi         74.0  $78,797      66.0    29.0
# 8       Oppo         53.0   $9,798       3.0    77.0
# 9        NaN          NaN       NaN      NaN     NaN

# %%
# Column = Vertrical line vala Data = "axis = 1"
# Row = Horizontal line vala Data = "axis = 0"
# rows or column mil kr bnati hn data

# %%
phone.to_csv('modified_phone.csv')

# %%
modified_phone.csv
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[190], line 1
# ----> 1 modified_phone.csv
#
# NameError: name 'modified_phone' is not defined

# %% [markdown]
# # HOW TO DESCRIBE DATA

# %%
# Attributes
phone.dtypes
# Functions()
# Out:
# motorolla    object
#  12mb        object
#  10000        int64
# dtype: object

# %%
phone.columns
# Out:
# Index(['phone', ' memory(mb)', ' price ', ' demand', 'supply'], dtype='object')

# %%
column = phone.columns

# %%
column
# Out:
# Index(['phone', ' memory', ' price ', ' demand', 'Unnamed: 4'], dtype='object')

# %%
phone.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
phone.describe()
# Out:
#         memory(mb)     demand      supply
# count     9.000000   9.000000    9.000000
# mean     56.444444  30.666667   43.666667
# std      35.359267  20.754518   62.483998
# min      10.000000   3.000000    2.000000
# 25%      18.000000  20.000000   14.000000
# 50%      67.000000  23.000000   19.000000
# 75%      77.000000  40.000000   29.000000
# max      99.000000  66.000000  200.000000

# %%
phone.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   phone        9 non-null      object
#  1    memory(mb)  9 non-null      float64
#  2    price       9 non-null      object
#  3    demand      9 non-null      float64
#  4   supply       9 non-null      float64
# dtypes: float64(3), object(2)
# memory usage: 532.0+ bytes

# %%
phone.mean()
# Out:
# C:\Users\bilal\AppData\Local\Temp\ipykernel_10512\1329539133.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   phone.mean()
#  memory(mb)    56.444444
#  demand        30.666667
# supply         43.666667
# dtype: float64

# %%
phone['memory'].sum
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\ML_Project\venv\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\ML_Project\venv\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\ML_Project\venv\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'memory'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# # Data Selection

# %%
phoone.head
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 phoone.head
#
# NameError: name 'phoone' is not defined

# %%
phone.head(1)
# Out:
#   motorolla  12mb    10000
# 0     nokia   10mb    8799

# %%
phone.head
# Out:
# <bound method NDFrame.head of        phone   memory(mb)    price    demand  supply
# 0  motorolla         12.0   $1,000      20.0    14.0
# 1    samsung         10.0   $8,799      40.0    18.0
# 2      nokia         18.0   $9,799      60.0    26.0
# 3     huawei         98.0   $9,890      16.0     2.0
# 4     Iphone         67.0  $90,909      22.0     8.0
# 5         LG         77.0   $8,686      26.0   200.0
# 6       Oppo         99.0   $5,778      23.0    19.0
# 7       Vovi         74.0  $78,797      66.0    29.0
# 8       Oppo         53.0   $9,798       3.0    77.0
# 9        NaN          NaN       NaN      NaN     NaN>

# %%
phone.tail(2)
# Out:
#   phone   memory(mb)   price    demand  supply
# 8  Oppo         53.0  $9,798       3.0    77.0
# 9   NaN          NaN      NaN      NaN     NaN

# %% [markdown]
# # Index (.loc) or Location(.iloc)

# %%
birds = pd.Series(['pigeon', 'crow',' Sparrow', 'Parrot', 'Eagle', 'SEagull'],index = [0,3,9,8,6,5])

# %%
birds
# Out:
# 0      pigeon
# 3        crow
# 9     Sparrow
# 8      Parrot
# 6       Eagle
# 5     SEagull
# dtype: object

# %%
birds.loc[3]
# Out:
# 'crow'

# %%
birds.iloc[1]
# Out:
# 'crow'

# %%
phoone = pd.read_csv('phone.csv')

# %%
phoone
# Out:
#        phone   memory(mb)    price    demand  supply
# 0  motorolla         12.0   $1,000      20.0    14.0
# 1    samsung         10.0   $8,799      40.0    18.0
# 2      nokia         18.0   $9,799      60.0    26.0
# 3     huawei         98.0   $9,890      16.0     2.0
# 4     Iphone         67.0  $90,909      22.0     8.0
# 5         LG         77.0   $8,686      26.0   200.0
# 6       Oppo         99.0   $5,778      23.0    19.0
# 7       Vovi         74.0  $78,797      66.0    29.0
# 8       Oppo         53.0   $9,798       3.0    77.0
# 9        NaN          NaN       NaN      NaN     NaN

# %%
phoone.loc[5] #Indexing
# Out:
# phone        Iphone
#  memory        67mb
#  price     $90,909
# Name: 5, dtype: object

# %%
phoone.iloc[5] # Position
# Out:
# phone        Iphone
#  memory        67mb
#  price     $90,909
# Name: 5, dtype: object

# %%
phone.iloc[:3]
# Out:
#        phone  memory    price
# 0        NaN     NaN      NaN
# 1  motorolla   12mb   $1,000
# 2      nokia    10mb  $8,799

# %%
phoone.head(3)
# Out:
#        phone  memory    price
# 0        NaN     NaN      NaN
# 1  motorolla   12mb   $1,000
# 2      nokia    10mb  $8,799

# %%
phoone['phone']
# Out:
# 0          NaN
# 1    motorolla
# 2        nokia
# 3      samsung
# 4       huawei
# 5       Iphone
# 6           LG
# 7        Tecno
# 8         Oppo
# 9         Vovi
# Name: phone, dtype: object

# %%
phoone.phone
# Out:
# 0    motorolla
# 1      samsung
# 2        nokia
# 3       huawei
# 4       Iphone
# 5           LG
# 6         Oppo
# 7         Vovi
# 8         Oppo
# 9          NaN
# Name: phone, dtype: object

# %%
phoone[phoone['memory'] >='50mb' ]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\ML_Project\venv\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\ML_Project\venv\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\ML_Project\venv\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'memory'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# # Data Selection 2

# %%
phone = pd.read_csv("phone.csv")

# %%
phone
# Out:
#        phone   memory(mb)    price    demand  supply
# 0  motorolla         12.0   $1,000      20.0    14.0
# 1    samsung         10.0   $8,799      40.0    18.0
# 2      nokia         18.0   $9,799      60.0    26.0
# 3     huawei         98.0   $9,890      16.0     2.0
# 4     Iphone         67.0  $90,909      22.0     8.0
# 5         LG         77.0   $8,686      26.0   200.0
# 6       Oppo         99.0   $5,778      23.0    19.0
# 7       Vovi         74.0  $78,797      66.0    29.0
# 8       Oppo         53.0   $9,798       3.0    77.0
# 9        NaN          NaN       NaN      NaN     NaN

# %%
# To compare 2 columns
# pd.crosstab()
pd.crosstab(phone['phone'],phone['demand'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\ML_Project\venv\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\ML_Project\venv\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\ML_Project\venv\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'demand'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# More than two command to compare
phone.groupby(['phone']).mean()
# Out:
# C:\Users\bilal\AppData\Local\Temp\ipykernel_10512\923572956.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   phone.groupby(['phone']).mean()
#             memory(mb)   demand  supply
# phone
# Iphone            67.0     22.0     8.0
# LG                77.0     26.0   200.0
# Oppo              76.0     13.0    48.0
# Vovi              74.0     66.0    29.0
# huawei            98.0     16.0     2.0
# motorolla         12.0     20.0    14.0
# nokia             18.0     60.0    26.0
# samsung           10.0     40.0    18.0

# %%
phone.dtypes
# Out:
# phone          object
#  memory        object
#  price         object
#  demand       float64
# Unnamed: 4    float64
# dtype: object

# %% [markdown]
# #  How to plot Data

# %%
phone['demand'].plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\ML_Project\venv\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\ML_Project\venv\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\ML_Project\venv\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'demand'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
heart = pd.read_csv("heart.csv")

# %%
heart
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
heart.head(8)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
# 5   39   M           NAP        120          339          0     Normal    170
# 6   45   F           ATA        130          237          0     Normal    170
# 7   54   M           ATA        110          208          0     Normal    142
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# ...

# %%
heart.dtypes
# Out:
# Age                 int64
# Sex                object
# ChestPainType      object
# RestingBP           int64
# Cholesterol         int64
# FastingBS           int64
# RestingECG         object
# MaxHR               int64
# ExerciseAngina     object
# Oldpeak           float64
# ST_Slope           object
# HeartDisease        int64
# dtype: object

# %%
heart['Cholesterol'].plot()
# Out:
# <Axes: >

# %%
heart['FastingBS'].plot()
# Out:
# <Axes: >

# %%
heart['Cholesterol'].hist()
# Out:
# <Axes: >

# %%
heart['FastingBS'].hist()
# Out:
# <Axes: >

# %%
phone['price'].str.replace('[\$]','').astype(int)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\ML_Project\venv\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\ML_Project\venv\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\ML_Project\venv\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'price'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\ML_Project\venv\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\ML_Project\venv\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\ML_Project\venv\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'price'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# # Changing Data

# %%
heart
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
phone
# Out:
#        phone   memory(mb)    price    demand  supply
# 0  motorolla         12.0   $1,000      20.0    14.0
# 1    samsung         10.0   $8,799      40.0    18.0
# 2      nokia         18.0   $9,799      60.0    26.0
# 3     huawei         98.0   $9,890      16.0     2.0
# 4     Iphone         67.0  $90,909      22.0     8.0
# 5         LG         77.0   $8,686      26.0   200.0
# 6       Oppo         99.0   $5,778      23.0    19.0
# 7       Vovi         74.0  $78,797      66.0    29.0
# 8       Oppo         53.0   $9,798       3.0    77.0
# 9        NaN          NaN       NaN      NaN     NaN

# %%
phone['price'].str.lower
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\ML_Project\venv\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\ML_Project\venv\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\ML_Project\venv\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'price'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
phone_missing = pd.read_csv('phone_MissingValues.csv')

# %%
phone_missing
# Out:
#         phone   memory(mb)    price    demand  supply
# 0      huawei         98.0   $9,890      16.0     2.0
# 1      Iphone         67.0  $90,909      22.0     8.0
# 2   motorolla          NaN   $1,000      20.0    14.0
# 3     samsung         10.0   $8,799      40.0    18.0
# 4        Oppo         99.0       NaN     23.0    19.0
# 5       nokia         18.0   $9,799      60.0    26.0
# 6        Vovi         74.0  $78,797      66.0    29.0
# 7         NaN          NaN       NaN      NaN     NaN
# 8          LG         77.0   $8,686      26.0   200.0
# 9      Tamsun         88.0   $8,798      99.0     NaN
# 10        NaN          NaN       NaN      NaN     NaN
# 11        NaN          NaN       NaN      NaN     NaN
# 12    Infinix          3.0      $77       9.0    87.0

# %% [markdown]
# # Method To fill Empty Data

# %%
phone_missing
# Out:
#         phone   memory(mb)    price    demand  supply
# 0      huawei         98.0   $9,890      16.0     2.0
# 1      Iphone         67.0  $90,909      22.0     8.0
# 2   motorolla          NaN   $1,000      20.0    14.0
# 3     samsung         10.0   $8,799      40.0    18.0
# 4        Oppo         99.0       NaN     23.0    19.0
# 5       nokia         18.0   $9,799      60.0    26.0
# 6        Vovi         74.0  $78,797      66.0    29.0
# 7         NaN          NaN       NaN      NaN     NaN
# 8          LG         77.0   $8,686      26.0   200.0
# 9      Tamsun         88.0   $8,798      99.0     NaN
# 10        NaN          NaN       NaN      NaN     NaN
# 11        NaN          NaN       NaN      NaN     NaN
# 12    Infinix          3.0      $77       9.0    87.0

# %%
phone_missing['supply'].mean()
# Out:
# 44.77777777777778

# %%
phone_missing['supply'].fillna(phone_missing['supply'].mean())
# Out:
# 0       2.000000
# 1       8.000000
# 2      14.000000
# 3      18.000000
# 4      19.000000
# 5      26.000000
# 6      29.000000
# 7      44.777778
# 8     200.000000
# 9      44.777778
# 10     44.777778
# 11     44.777778
# 12     87.000000
# Name: supply, dtype: float64

# %%
phone_missing
# Out:
#         phone   memory(mb)    price    demand      supply
# 0      huawei         98.0   $9,890      16.0    2.000000
# 1      Iphone         67.0  $90,909      22.0    8.000000
# 2   motorolla          NaN   $1,000      20.0   14.000000
# 3     samsung         10.0   $8,799      40.0   18.000000
# 4        Oppo         99.0       NaN     23.0   19.000000
# 5       nokia         18.0   $9,799      60.0   26.000000
# 6        Vovi         74.0  $78,797      66.0   29.000000
# 7         NaN          NaN       NaN      NaN   44.777778
# 8          LG         77.0   $8,686      26.0  200.000000
# 9      Tamsun         88.0   $8,798      99.0   44.777778
# 10        NaN          NaN       NaN      NaN   44.777778
# 11        NaN          NaN       NaN      NaN   44.777778
# 12    Infinix          3.0      $77       9.0   87.000000

# %%
phone_missing['supply'].fillna(phone_missing['supply'].mean(), inplace = True)

# %%
phone_missing
# Out:
#         phone   memory(mb)    price    demand      supply
# 0      huawei         98.0   $9,890      16.0    2.000000
# 1      Iphone         67.0  $90,909      22.0    8.000000
# 2   motorolla          NaN   $1,000      20.0   14.000000
# 3     samsung         10.0   $8,799      40.0   18.000000
# 4        Oppo         99.0       NaN     23.0   19.000000
# 5       nokia         18.0   $9,799      60.0   26.000000
# 6        Vovi         74.0  $78,797      66.0   29.000000
# 7         NaN          NaN       NaN      NaN   44.777778
# 8          LG         77.0   $8,686      26.0  200.000000
# 9      Tamsun         88.0   $8,798      99.0   44.777778
# 10        NaN          NaN       NaN      NaN   44.777778
# 11        NaN          NaN       NaN      NaN   44.777778
# 12    Infinix          3.0      $77       9.0   87.000000

# %%
# Saary NaN hatany k lie
phone_missing.dropna()
# Out:
#       phone   memory(mb)    price    demand      supply
# 0    huawei         98.0   $9,890      16.0    2.000000
# 1    Iphone         67.0  $90,909      22.0    8.000000
# 3   samsung         10.0   $8,799      40.0   18.000000
# 5     nokia         18.0   $9,799      60.0   26.000000
# 6      Vovi         74.0  $78,797      66.0   29.000000
# 8        LG         77.0   $8,686      26.0  200.000000
# 9    Tamsun         88.0   $8,798      99.0   44.777778
# 12  Infinix          3.0      $77       9.0   87.000000

# %%
phone_missing
# Out:
#         phone   memory(mb)    price    demand      supply
# 0      huawei         98.0   $9,890      16.0    2.000000
# 1      Iphone         67.0  $90,909      22.0    8.000000
# 2   motorolla          NaN   $1,000      20.0   14.000000
# 3     samsung         10.0   $8,799      40.0   18.000000
# 4        Oppo         99.0       NaN     23.0   19.000000
# 5       nokia         18.0   $9,799      60.0   26.000000
# 6        Vovi         74.0  $78,797      66.0   29.000000
# 7         NaN          NaN       NaN      NaN   44.777778
# 8          LG         77.0   $8,686      26.0  200.000000
# 9      Tamsun         88.0   $8,798      99.0   44.777778
# 10        NaN          NaN       NaN      NaN   44.777778
# 11        NaN          NaN       NaN      NaN   44.777778
# 12    Infinix          3.0      $77       9.0   87.000000

# %%
heart
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
heart['age'].plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\ML_Project\venv\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\ML_Project\venv\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\ML_Project\venv\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'age'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# # Add REmove and Change Columns

# %%
phone_csv = pd.read_csv('phone.csv')

# %%
phone_csv
# Out:
#        phone   memory(mb)    price    demand  supply
# 0  motorolla         12.0   $1,000      20.0    14.0
# 1    samsung         10.0   $8,799      40.0    18.0
# 2      nokia         18.0   $9,799      60.0    26.0
# 3     huawei         98.0   $9,890      16.0     2.0
# 4     Iphone         67.0  $90,909      22.0     8.0
# 5         LG         77.0   $8,686      26.0   200.0
# 6       Oppo         99.0   $5,778      23.0    19.0
# 7       Vovi         74.0  $78,797      66.0    29.0
# 8       Oppo         53.0   $9,798       3.0    77.0
# 9        NaN          NaN       NaN      NaN     NaN

# %%
batteries = pd.Series([3,45,6,3,7])

phone_csv['battery'] = batteries

# %%
phone_csv
# Out:
#        phone   memory(mb)    price    demand  supply  battery
# 0  motorolla         12.0   $1,000      20.0    14.0      3.0
# 1    samsung         10.0   $8,799      40.0    18.0     45.0
# 2      nokia         18.0   $9,799      60.0    26.0      6.0
# 3     huawei         98.0   $9,890      16.0     2.0      3.0
# 4     Iphone         67.0  $90,909      22.0     8.0      7.0
# 5         LG         77.0   $8,686      26.0   200.0      NaN
# 6       Oppo         99.0   $5,778      23.0    19.0      NaN
# 7       Vovi         74.0  $78,797      66.0    29.0      NaN
# 8       Oppo         53.0   $9,798       3.0    77.0      NaN
# 9        NaN          NaN       NaN      NaN     NaN      NaN

# %%
phone_csv['battery'].fillna(5, inplace = True)

# %%
phone_csv
# Out:
#        phone   memory(mb)    price    demand  supply  battery
# 0  motorolla         12.0   $1,000      20.0    14.0      3.0
# 1    samsung         10.0   $8,799      40.0    18.0     45.0
# 2      nokia         18.0   $9,799      60.0    26.0      6.0
# 3     huawei         98.0   $9,890      16.0     2.0      3.0
# 4     Iphone         67.0  $90,909      22.0     8.0      7.0
# 5         LG         77.0   $8,686      26.0   200.0      5.0
# 6       Oppo         99.0   $5,778      23.0    19.0      5.0
# 7       Vovi         74.0  $78,797      66.0    29.0      5.0
# 8       Oppo         53.0   $9,798       3.0    77.0      5.0
# 9        NaN          NaN       NaN      NaN     NaN      5.0

# %%
ringtones = [5,6,7,8,1,2,3,5,6,0]
phone_csv['Ringtones'] = ringtones

# %%
phone_csv
# Out:
#        phone   memory(mb)    price    demand  supply  battery  Ringtones
# 0  motorolla         12.0   $1,000      20.0    14.0      3.0          5
# 1    samsung         10.0   $8,799      40.0    18.0     45.0          6
# 2      nokia         18.0   $9,799      60.0    26.0      6.0          7
# 3     huawei         98.0   $9,890      16.0     2.0      3.0          8
# 4     Iphone         67.0  $90,909      22.0     8.0      7.0          1
# 5         LG         77.0   $8,686      26.0   200.0      5.0          2
# 6       Oppo         99.0   $5,778      23.0    19.0      5.0          3
# 7       Vovi         74.0  $78,797      66.0    29.0      5.0          5
# 8       Oppo         53.0   $9,798       3.0    77.0      5.0          6
# 9        NaN          NaN       NaN      NaN     NaN      5.0          0

# %%
phone_csv['mailJhol'] = phone_csv['battery']*phone_csv['Ringtones']

# %%
phone_csv
# Out:
#        phone   memory(mb)    price    demand  supply  battery  Ringtones  \
# 0  motorolla         12.0   $1,000      20.0    14.0      3.0          5
# 1    samsung         10.0   $8,799      40.0    18.0     45.0          6
# 2      nokia         18.0   $9,799      60.0    26.0      6.0          7
# 3     huawei         98.0   $9,890      16.0     2.0      3.0          8
# 4     Iphone         67.0  $90,909      22.0     8.0      7.0          1
# 5         LG         77.0   $8,686      26.0   200.0      5.0          2
# 6       Oppo         99.0   $5,778      23.0    19.0      5.0          3
# 7       Vovi         74.0  $78,797      66.0    29.0      5.0          5
# 8       Oppo         53.0   $9,798       3.0    77.0      5.0          6
# 9        NaN          NaN       NaN      NaN     NaN      5.0          0
#
#    mailJhol
# 0      15.0
# 1     270.0
# 2      42.0
# 3      24.0
# 4       7.0
# 5      10.0
# 6      15.0
# 7      25.0
# 8      30.0
# 9       0.0

# %%
phone_csv['New_col'] = 3

# %%
phone_csv
# Out:
#        phone   memory(mb)    price    demand  supply  battery  Ringtones  \
# 0  motorolla         12.0   $1,000      20.0    14.0      3.0          5
# 1    samsung         10.0   $8,799      40.0    18.0     45.0          6
# 2      nokia         18.0   $9,799      60.0    26.0      6.0          7
# 3     huawei         98.0   $9,890      16.0     2.0      3.0          8
# 4     Iphone         67.0  $90,909      22.0     8.0      7.0          1
# 5         LG         77.0   $8,686      26.0   200.0      5.0          2
# 6       Oppo         99.0   $5,778      23.0    19.0      5.0          3
# 7       Vovi         74.0  $78,797      66.0    29.0      5.0          5
# 8       Oppo         53.0   $9,798       3.0    77.0      5.0          6
# 9        NaN          NaN       NaN      NaN     NaN      5.0          0
#
#    mailJhol  New_col
# 0      15.0        3
# 1     270.0        3
# 2      42.0        3
# 3      24.0        3
# 4       7.0        3
# 5      10.0        3
# ...

# %%
phone_csv['old_col'] = True

# %%
phone_csv
# Out:
#        phone   memory(mb)    price    demand  supply  battery  Ringtones  \
# 0  motorolla         12.0   $1,000      20.0    14.0      3.0          5
# 1    samsung         10.0   $8,799      40.0    18.0     45.0          6
# 2      nokia         18.0   $9,799      60.0    26.0      6.0          7
# 3     huawei         98.0   $9,890      16.0     2.0      3.0          8
# 4     Iphone         67.0  $90,909      22.0     8.0      7.0          1
# 5         LG         77.0   $8,686      26.0   200.0      5.0          2
# 6       Oppo         99.0   $5,778      23.0    19.0      5.0          3
# 7       Vovi         74.0  $78,797      66.0    29.0      5.0          5
# 8       Oppo         53.0   $9,798       3.0    77.0      5.0          6
# 9        NaN          NaN       NaN      NaN     NaN      5.0          0
#
#    mailJhol  New_col  old_col
# 0      15.0        3     True
# 1     270.0        3     True
# 2      42.0        3     True
# 3      24.0        3     True
# ...

# %%
phone_csv.dtypes
# Out:
# phone           object
#  memory(mb)    float64
#  price          object
#  demand        float64
# supply         float64
# battery        float64
# Ringtones        int64
# mailJhol       float64
# New_col          int64
# old_col           bool
# dtype: object

# %%
phone_csv['New_col'].plot()
# Out:
# <Axes: >

# %%
phone_csv['New_col'].hist()
# Out:
# <Axes: >

# %%
phone_csv.drop('New_col', axis = 1)
# Out:
#        phone   memory(mb)    price    demand  supply  battery  Ringtones  \
# 0  motorolla         12.0   $1,000      20.0    14.0      3.0          5
# 1    samsung         10.0   $8,799      40.0    18.0     45.0          6
# 2      nokia         18.0   $9,799      60.0    26.0      6.0          7
# 3     huawei         98.0   $9,890      16.0     2.0      3.0          8
# 4     Iphone         67.0  $90,909      22.0     8.0      7.0          1
# 5         LG         77.0   $8,686      26.0   200.0      5.0          2
# 6       Oppo         99.0   $5,778      23.0    19.0      5.0          3
# 7       Vovi         74.0  $78,797      66.0    29.0      5.0          5
# 8       Oppo         53.0   $9,798       3.0    77.0      5.0          6
# 9        NaN          NaN       NaN      NaN     NaN      5.0          0
#
#    mailJhol  old_col
# 0      15.0     True
# 1     270.0     True
# 2      42.0     True
# 3      24.0     True
# 4       7.0     True
# 5      10.0     True
# ...

# %%
phone_csv
# Out:
#        phone   memory(mb)    price    demand  supply  battery  Ringtones  \
# 0  motorolla         12.0   $1,000      20.0    14.0      3.0          5
# 1    samsung         10.0   $8,799      40.0    18.0     45.0          6
# 2      nokia         18.0   $9,799      60.0    26.0      6.0          7
# 3     huawei         98.0   $9,890      16.0     2.0      3.0          8
# 4     Iphone         67.0  $90,909      22.0     8.0      7.0          1
# 5         LG         77.0   $8,686      26.0   200.0      5.0          2
# 6       Oppo         99.0   $5,778      23.0    19.0      5.0          3
# 7       Vovi         74.0  $78,797      66.0    29.0      5.0          5
# 8       Oppo         53.0   $9,798       3.0    77.0      5.0          6
# 9        NaN          NaN       NaN      NaN     NaN      5.0          0
#
#    mailJhol  New_col  old_col
# 0      15.0        3     True
# 1     270.0        3     True
# 2      42.0        3     True
# 3      24.0        3     True
# ...

# %%
phone_csv.drop('New_col', axis = 1, inplace =True)

# %%
phone_csv
# Out:
#        phone   memory(mb)    price    demand  supply  battery  Ringtones  \
# 0  motorolla         12.0   $1,000      20.0    14.0      3.0          5
# 1    samsung         10.0   $8,799      40.0    18.0     45.0          6
# 2      nokia         18.0   $9,799      60.0    26.0      6.0          7
# 3     huawei         98.0   $9,890      16.0     2.0      3.0          8
# 4     Iphone         67.0  $90,909      22.0     8.0      7.0          1
# 5         LG         77.0   $8,686      26.0   200.0      5.0          2
# 6       Oppo         99.0   $5,778      23.0    19.0      5.0          3
# 7       Vovi         74.0  $78,797      66.0    29.0      5.0          5
# 8       Oppo         53.0   $9,798       3.0    77.0      5.0          6
# 9        NaN          NaN       NaN      NaN     NaN      5.0          0
#
#    mailJhol  old_col
# 0      15.0     True
# 1     270.0     True
# 2      42.0     True
# 3      24.0     True
# 4       7.0     True
# 5      10.0     True
# ...

# %% [markdown]
# # Manipulating Data

# %%
phone_csv.sample(frac=.4)
# Out:
#    phone   memory(mb)    price    demand  supply  battery  Ringtones  \
# 6   Oppo         99.0   $5,778      23.0    19.0      5.0          3
# 8   Oppo         53.0   $9,798       3.0    77.0      5.0          6
# 2  nokia         18.0   $9,799      60.0    26.0      6.0          7
# 7   Vovi         74.0  $78,797      66.0    29.0      5.0          5
#
#    mailJhol  old_col
# 6      15.0     True
# 8      30.0     True
# 2      42.0     True
# 7      25.0     True

# %%
phone_csv
# Out:
#        phone   memory(mb)    price    demand  supply  battery  Ringtones  \
# 0  motorolla         12.0   $1,000      20.0    14.0      3.0          5
# 1    samsung         10.0   $8,799      40.0    18.0     45.0          6
# 2      nokia         18.0   $9,799      60.0    26.0      6.0          7
# 3     huawei         98.0   $9,890      16.0     2.0      3.0          8
# 4     Iphone         67.0  $90,909      22.0     8.0      7.0          1
# 5         LG         77.0   $8,686      26.0   200.0      5.0          2
# 6       Oppo         99.0   $5,778      23.0    19.0      5.0          3
# 7       Vovi         74.0  $78,797      66.0    29.0      5.0          5
# 8       Oppo         53.0   $9,798       3.0    77.0      5.0          6
# 9        NaN          NaN       NaN      NaN     NaN      5.0          0
#
#    mailJhol  old_col
# 0      15.0     True
# 1     270.0     True
# 2      42.0     True
# 3      24.0     True
# 4       7.0     True
# 5      10.0     True
# ...

# %%
phone_csv.reset_index(drop = True, inplace = True)

# %%
phone_csv
# Out:
#        phone   memory(mb)    price    demand  supply  battery  Ringtones  \
# 0  motorolla         12.0   $1,000      20.0    14.0      3.0          5
# 1    samsung         10.0   $8,799      40.0    18.0     45.0          6
# 2      nokia         18.0   $9,799      60.0    26.0      6.0          7
# 3     huawei         98.0   $9,890      16.0     2.0      3.0          8
# 4     Iphone         67.0  $90,909      22.0     8.0      7.0          1
# 5         LG         77.0   $8,686      26.0   200.0      5.0          2
# 6       Oppo         99.0   $5,778      23.0    19.0      5.0          3
# 7       Vovi         74.0  $78,797      66.0    29.0      5.0          5
# 8       Oppo         53.0   $9,798       3.0    77.0      5.0          6
# 9        NaN          NaN       NaN      NaN     NaN      5.0          0
#
#    mailJhol  old_col
# 0      15.0     True
# 1     270.0     True
# 2      42.0     True
# 3      24.0     True
# 4       7.0     True
# 5      10.0     True
# ...

# %%
phone_csv
# Out:
#        phone   memory(mb)    price    demand  supply  battery  Ringtones  \
# 0  motorolla         12.0   $1,000      20.0    14.0      3.0          5
# 1    samsung         10.0   $8,799      40.0    18.0     45.0          6
# 2      nokia         18.0   $9,799      60.0    26.0      6.0          7
# 3     huawei         98.0   $9,890      16.0     2.0      3.0          8
# 4     Iphone         67.0  $90,909      22.0     8.0      7.0          1
# 5         LG         77.0   $8,686      26.0   200.0      5.0          2
# 6       Oppo         99.0   $5,778      23.0    19.0      5.0          3
# 7       Vovi         74.0  $78,797      66.0    29.0      5.0          5
# 8       Oppo         53.0   $9,798       3.0    77.0      5.0          6
# 9        NaN          NaN       NaN      NaN     NaN      5.0          0
#
#    mailJhol  old_col
# 0      15.0     True
# 1     270.0     True
# 2      42.0     True
# 3      24.0     True
# 4       7.0     True
# 5      10.0     True
# ...

# %%
phone_csv['memory(mb)'] = phone_csv['memory(kb)'].apply
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\ML_Project\venv\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\ML_Project\venv\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\ML_Project\venv\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'memory(kb)'
#
# The above exception was the direct cause of the following exception:
#
# ...
